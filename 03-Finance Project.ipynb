# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
# ____
# ** NOTE: This project is extremely challenging because it will introduce a lot of new concepts and have you looking things up on your own (we'll point you in the right direction) to try to solve the tasks issued. Feel free to just go through the solutions lecture notebook and video as a "walkthrough" project if you don't want to have to look things up yourself. You'll still learn a lot that way! **
# ____
# We'll focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# In this section we will learn how to use pandas to directly read data from Google finance using pandas!
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
# *Note: [You'll need to install pandas-datareader for this to work!](https://github.com/pydata/pandas-datareader) Pandas datareader allows you to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use these links for install guidance (**pip install pandas-datareader**), or just follow along with the video lecture.*
#
# ### The Imports
#
# Already filled out for you.

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. This will involve a few steps:**
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.
#
# ** Use [this documentation page](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) for hints and instructions (it should just be a matter of replacing certain values. Use google finance as a source, for example:**
#
#     # Bank of America
#     BAC = data.DataReader("BAC", 'google', start, end)
#
# ### WARNING: MAKE SURE TO CHECK THE LINK ABOVE FOR THE LATEST WORKING API. "google" MAY NOT ALWAYS WORK.
# ------------
# ### We also provide pickle file in the article lecture right before the video lectures.

# %%
BAC = yf.download('BAC', start="2006-01-01", end="2016-01-01")
C = yf.download('C', start="2006-01-01", end="2016-01-01")
GS = yf.download('GS', start="2006-01-01", end="2016-01-01")
JPM = yf.download('JPM', start="2006-01-01", end="2016-01-01")
MS = yf.download('MS', start="2006-01-01", end="2016-01-01")
WFC = yf.download('WFC', start="2006-01-01", end="2016-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
BAC
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  32.425449  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  32.081074  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  32.122395  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  32.074184  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  32.094852  15619400
# ...               ...        ...        ...        ...        ...       ...
# 2015-12-24  17.320000  17.379999  17.219999  17.270000  14.669742  29369400
# 2015-12-28  17.219999  17.230000  16.980000  17.129999  14.550817  41777500
# 2015-12-29  17.250000  17.350000  17.160000  17.280001  14.678232  45670400
# 2015-12-30  17.200001  17.240000  17.040001  17.049999  14.482863  35066400
# 2015-12-31  17.010000  17.070000  16.830000  16.830000  14.295989  47153000
#
# [2517 rows x 6 columns]

# %%
C
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2006-01-03  490.000000  493.799988  481.100006  492.899994  338.403259
# 2006-01-04  488.600006  491.000000  483.500000  483.799988  332.155609
# 2006-01-05  484.399994  487.799988  484.000000  486.200012  333.803314
# 2006-01-06  488.799988  489.000000  482.000000  486.200012  333.803314
# 2006-01-09  486.000000  487.399994  483.000000  483.899994  332.224304
# ...                ...         ...         ...         ...         ...
# 2015-12-24   52.480000   52.970001   52.450001   52.709999   41.972157
# 2015-12-28   52.570000   52.570000   51.959999   52.380001   41.709389
# 2015-12-29   52.759998   53.220001   52.740002   52.980000   42.187153
# 2015-12-30   52.840000   52.939999   52.250000   52.299999   41.645679
# 2015-12-31   52.070000   52.389999   51.750000   51.750000   41.207733
#
#               Volume
# Date
# 2006-01-03   1537600
# 2006-01-04   1870960
# 2006-01-05   1143160
# ...

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
tickers = ['BAC','C','GS','JPM','MS','WFC']

# %% [markdown]
# ** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
bank_stocks = pd.concat([BAC,C,GS,JPM,MS,WFC],keys=tickers, axis=1)
bank_stocks
# Out:
#                   BAC                                                        \
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  32.425449  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  32.081074  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  32.122395  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  32.074184  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  32.094852  15619400
# ...               ...        ...        ...        ...        ...       ...
# 2015-12-24  17.320000  17.379999  17.219999  17.270000  14.669742  29369400
# 2015-12-28  17.219999  17.230000  16.980000  17.129999  14.550817  41777500
# 2015-12-29  17.250000  17.350000  17.160000  17.280001  14.678232  45670400
# 2015-12-30  17.200001  17.240000  17.040001  17.049999  14.482863  35066400
# ...

# %% [markdown]
# ** Set the column name levels (this is filled out for you):**

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %% [markdown]
# ** Check the head of the bank_stocks dataframe.**

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                                        \
# Stock Info        Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03   46.919998  47.180000  46.150002  47.080002  32.425449  16296700
# 2006-01-04   47.000000  47.240002  46.450001  46.580002  32.081074  17757900
# 2006-01-05   46.580002  46.830002  46.320000  46.639999  32.122395  14970700
# 2006-01-06   46.799999  46.910000  46.349998  46.570000  32.074184  12599800
# 2006-01-09   46.720001  46.970001  46.360001  46.599998  32.094852  15619400
#
# Bank Ticker           C                                      ...         MS  \
# Stock Info         Open        High         Low       Close  ...        Low
# Date                                                         ...
# 2006-01-03   490.000000  493.799988  481.100006  492.899994  ...  56.740002
# 2006-01-04   488.600006  491.000000  483.500000  483.799988  ...  58.349998
# ...

# %% [markdown]
# # EDA
#
# Let's explore the data a bit! Before continuing, I encourage you to check out the documentation on [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) and [Using .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Reference the solutions if you can not figure out how to use .xs(), since that will be a major part of this project.
#
# ** What is the max Close price for each bank's stock throughout the time period?**

# %%
bank_stocks['BAC']['Close'].max()
# Out:
# 54.900001525878906

# %%
for tick in tickers:
    print(tick, bank_stocks[tick]['Close'].max())
# Out:
# BAC 54.900001525878906
# C 564.0999755859375
# GS 247.9199981689453
# JPM 70.08000183105469
# MS 89.30000305175781
# WFC 58.52000045776367

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %% [markdown]
# ** We can use pandas pct_change() method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.**

# %%
tickers = ['BAC','C','GS','JPM','MS','WFC']
for bank in tickers:
    returns[bank + ' Returns'] = bank_stocks[bank]['Close'].pct_change()
returns

#returns[bank + ' Returns'] = : 這部分程式碼將上述計算的百分比變化賦值給新的returns資料框的一個新列。
#這個列的名稱將會是銀行代號加上一個字符串' Returns'。例如，如果當前的bank是'BAC'，新的列的名稱將會是'BAC Returns'。
# Out:
#             BAC Returns  C Returns  GS Returns  JPM Returns  MS Returns  \
# Date
# 2006-01-03          NaN        NaN         NaN          NaN         NaN
# 2006-01-04    -0.010620  -0.018462   -0.013812    -0.014183    0.000686
# 2006-01-05     0.001288   0.004961   -0.000393     0.003029    0.002742
# 2006-01-06    -0.001501   0.000000    0.014169     0.007046    0.001025
# 2006-01-09     0.000644  -0.004731    0.012030     0.016242    0.010586
# ...                 ...        ...         ...          ...         ...
# 2015-12-24    -0.004037   0.001520   -0.002624    -0.001948   -0.003681
# 2015-12-28    -0.008107  -0.006261   -0.004658    -0.003303   -0.009544
# 2015-12-29     0.008757   0.011455    0.010516     0.010395    0.011812
# 2015-12-30    -0.013310  -0.012835   -0.008282    -0.007157   -0.009831
# 2015-12-31    -0.012903  -0.010516   -0.009780    -0.008410   -0.013031
#
#             WFC Returns
# Date
# 2006-01-03          NaN
# 2006-01-04    -0.011599
# ...

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
sns.pairplot(returns[1:])

# %% [markdown]
# * See solution for details about Citigroup behavior....

# %% [markdown]
# ** Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
returns['BAC Returns'].idxmax()
# Out:
# Timestamp('2009-04-09 00:00:00')

# %%
returns.idxmax()
# Out:
# BAC Returns   2009-04-09
# C Returns     2008-11-24
# GS Returns    2008-11-24
# JPM Returns   2009-01-21
# MS Returns    2008-10-13
# WFC Returns   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ** You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame? **

# %%
returns['BAC Returns'].idxmin()
# Out:
# Timestamp('2009-01-20 00:00:00')

# %%
returns.idxmin()
# Out:
# BAC Returns   2009-01-20
# C Returns     2009-02-27
# GS Returns    2009-01-20
# JPM Returns   2009-01-20
# MS Returns    2008-10-09
# WFC Returns   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# * See Solution for details

# %% [markdown]
# ** Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %%
for bank in returns:
    print(bank, 'std', returns[bank].std())
# Out:
# BAC Returns std 0.036647428911353884
# C Returns std 0.03867175165181401
# GS Returns std 0.0253897637710445
# JPM Returns std 0.02766738425898574
# MS Returns std 0.03781922911717962
# WFC Returns std 0.03023753835745813

# %%
returns.std()
# Out:
# BAC Returns    0.036647
# C Returns      0.038672
# GS Returns     0.025390
# JPM Returns    0.027667
# MS Returns     0.037819
# WFC Returns    0.030238
# dtype: float64

# %%
returns.reset_index(inplace=True)
returns
# Out:
#            Date  BAC Returns  C Returns  GS Returns  JPM Returns  MS Returns  \
# 0    2006-01-03          NaN        NaN         NaN          NaN         NaN
# 1    2006-01-04    -0.010620  -0.018462   -0.013812    -0.014183    0.000686
# 2    2006-01-05     0.001288   0.004961   -0.000393     0.003029    0.002742
# 3    2006-01-06    -0.001501   0.000000    0.014169     0.007046    0.001025
# 4    2006-01-09     0.000644  -0.004731    0.012030     0.016242    0.010586
# ...         ...          ...        ...         ...          ...         ...
# 2512 2015-12-24    -0.004037   0.001520   -0.002624    -0.001948   -0.003681
# 2513 2015-12-28    -0.008107  -0.006261   -0.004658    -0.003303   -0.009544
# 2514 2015-12-29     0.008757   0.011455    0.010516     0.010395    0.011812
# 2515 2015-12-30    -0.013310  -0.012835   -0.008282    -0.007157   -0.009831
# 2516 2015-12-31    -0.012903  -0.010516   -0.009780    -0.008410   -0.013031
#
#       WFC Returns
# 0             NaN
# ...

# %%
returns['Date'][0].year
# Out:
# 2006

# %%
returns['Year'] = returns['Date'].apply(lambda time: time.year) 
returns
# Out:
#            Date  BAC Returns  C Returns  GS Returns  JPM Returns  MS Returns  \
# 0    2006-01-03          NaN        NaN         NaN          NaN         NaN
# 1    2006-01-04    -0.010620  -0.018462   -0.013812    -0.014183    0.000686
# 2    2006-01-05     0.001288   0.004961   -0.000393     0.003029    0.002742
# 3    2006-01-06    -0.001501   0.000000    0.014169     0.007046    0.001025
# 4    2006-01-09     0.000644  -0.004731    0.012030     0.016242    0.010586
# ...         ...          ...        ...         ...          ...         ...
# 2512 2015-12-24    -0.004037   0.001520   -0.002624    -0.001948   -0.003681
# 2513 2015-12-28    -0.008107  -0.006261   -0.004658    -0.003303   -0.009544
# 2514 2015-12-29     0.008757   0.011455    0.010516     0.010395    0.011812
# 2515 2015-12-30    -0.013310  -0.012835   -0.008282    -0.007157   -0.009831
# 2516 2015-12-31    -0.012903  -0.010516   -0.009780    -0.008410   -0.013031
#
#       WFC Returns  Year
# ...

# %%
returns2015 = returns[returns['Year']==2015]

bank_returns = ['BAC Returns','C Returns','GS Returns','JPM Returns','MS Returns','WFC Returns']
for bank in bank_returns:
    print(bank,'std:', returns2015[bank].std())
# Out:
# BAC Returns std: 0.016162568742018803
# C Returns std: 0.015289387324415937
# GS Returns std: 0.01404639855698666
# JPM Returns std: 0.014016841928251957
# MS Returns std: 0.016249117170001694
# WFC Returns std: 0.012591404257112995

# %%
#Which would you classify as the riskiest for the year 2015
#MS Returns

# %% [markdown]
# ** Create a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
sns.distplot(returns2015['MS Returns'], bins=120,color='green')
# Out:
# C:\Users\Tiffany\AppData\Local\Temp\ipykernel_39492\1403727295.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(returns2015['MS Returns'], bins=120,color='green')
# <Axes: xlabel='MS Returns', ylabel='Density'>

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
returns2008 = returns[returns['Year']==2008]
sns.displot(returns2008['C Returns'],bins=80,color='red',alpha=0.5,kde=True)

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
plt.figure(figsize=(21,7))

for bank in tickers:
    sns.lineplot(bank_stocks[bank]['Close'], label=bank, lw=3)

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
BAC.reset_index(inplace=True)
BAC
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2006-01-03  46.919998  47.180000  46.150002  47.080002  32.425449
# 1    2006-01-04  47.000000  47.240002  46.450001  46.580002  32.081074
# 2    2006-01-05  46.580002  46.830002  46.320000  46.639999  32.122395
# 3    2006-01-06  46.799999  46.910000  46.349998  46.570000  32.074184
# 4    2006-01-09  46.720001  46.970001  46.360001  46.599998  32.094852
# ...         ...        ...        ...        ...        ...        ...
# 2512 2015-12-24  17.320000  17.379999  17.219999  17.270000  14.669742
# 2513 2015-12-28  17.219999  17.230000  16.980000  17.129999  14.550817
# 2514 2015-12-29  17.250000  17.350000  17.160000  17.280001  14.678232
# 2515 2015-12-30  17.200001  17.240000  17.040001  17.049999  14.482863
# 2516 2015-12-31  17.010000  17.070000  16.830000  16.830000  14.295989
#
#         Volume
# 0     16296700
# 1     17757900
# 2     14970700
# 3     12599800
# 4     15619400
# ...        ...
# ...

# %%
BAC['Year']=BAC['Date'].apply(lambda time: time.year)
BAC_2008 = BAC[BAC['Year'] == 2008]
BAC_2008['30 Day Avg'] = BAC_2008['Close'].rolling(window=30).mean()

# %%
plt.figure(figsize=(12,4))
sns.lineplot(x='Date', y='Close', data=BAC_2008, label='BAC Close')
sns.lineplot(x='Date', y='30 Day Avg', data=BAC_2008, label='30 Day Avg')
# Out:
# <Axes: xlabel='Date', ylabel='Close'>

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr()
# Out:
# Bank Ticker       BAC         C        GS       JPM        MS       WFC
# Bank Ticker
# BAC          1.000000  0.971516  0.550898  0.103874  0.944218  0.008542
# C            0.971516  1.000000  0.434123  0.003515  0.933609 -0.068536
# GS           0.550898  0.434123  1.000000  0.685286  0.683792  0.499897
# JPM          0.103874  0.003515  0.685286  1.000000  0.250427  0.940269
# MS           0.944218  0.933609  0.683792  0.250427  1.000000  0.131835
# WFC          0.008542 -0.068536  0.499897  0.940269  0.131835  1.000000

# %%
#Correlation between the closing prices of the stocks
sns.heatmap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot=True)
# Out:
# <Axes: xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %% [markdown]
# ** Optional: Use seaborn's clustermap to cluster the correlations together:**

# %%
sns.clustermap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot=True)

# %% [markdown]
# # Part 2 (Optional)
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots. This part of the project is experimental due to its heavy reliance on the cuffinks project, so feel free to skip it if any functionality is broken in the future.

# %%
close_corr = bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr()

# %%
close_corr.iplot(kind='heatmap', colorscale='rdylbu')
# Out:
# <div>                            <div id="f612a69a-4028-4c38-8f30-5e906fb274b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
bac15 = BAC.loc['2015-01-01':'2016-01-01',['Open','High','Low','Close']]
bac15.iplot(kind='candle')
# Out:
# <div>                            <div id="08fd2bae-c2f8-44da-80b1-da4c2117ea33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
MS.loc['2015-01-01':'2016-01-01']['Close'].ta_plot(study='sma')
# Out:
# <div>                            <div id="fa5553d9-6161-43fa-aff0-26bb5d464ee3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
BAC.loc['2015-01-01':'2016-01-01']['Close'].ta_plot(study='boll')
# Out:
# <div>                            <div id="45a1061f-dc06-46df-a2ce-16b953bd877c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Great Job!
#
# Definitely a lot of more specific finance topics here, so don't worry if you didn't understand them all! The only thing you should be concerned with understanding are the basic pandas and visualization oeprations.
